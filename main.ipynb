# %% [markdown]
# Решаем задачу предсказания выжил ли пассажир в Титанике
#
# Ссылка на соревнование: https://www.kaggle.com/competitions/titanic/overview

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Загрузка данных

# %%
train_data = pd.read_csv("./train.csv")
test_data = pd.read_csv("./test.csv")
gender = pd.read_csv("./gender_submission.csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #### Baseline
# Построим Random Forest как бейзлайн модель для решения данной задачи. Так как построение случайного леса не требует много вычислительных ресурсов.

# %%
from sklearn.ensemble import RandomForestClassifier

Y_train = train_data["Survived"].copy()

features = ["Pclass", "Sex", "SibSp", "Parch"]
X_train = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('submission_forest.csv', index=False)

# %% [markdown]
# Получили score = 0.77272. Неплохо, давайте попробуем улучшить модель

# %% [markdown]
# Проведем feature engineering

# %%
import re


def clean_data(df):
    data = df.copy()

    # Заполним Na значения в поле Age медианой
    data['Age'].fillna(data["Age"].median(), inplace=True)
    
    
    # Заполним Na значения в порту направления 
    data['Embarked'].fillna("S", inplace=True)
    
    # Создадим фичу количество родственников пассажира
    data['Family'] = data['SibSp'] + data['Parch']
    
    # Поменяем не численные признаки на численные
    g = pd.get_dummies([], data['Sex'], drop_first = True)
    e = pd.get_dummies(data['Embarked'], drop_first = True)
    p = pd.get_dummies(data['Pclass'], drop_first = True)
    data = pd.concat([g,data,e,p], axis =1)
    data['is_minor']=np.where(data['Age']<=16,1,0)
    data.columns = data.columns.astype(str)
    # вычленим Mr Miss Mrs Master Rare из имени
    data['Words_Count'] = data['Name'].apply(lambda x: len(x.split()))
    data['Title'] = data.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
    data['Title'] = data['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    data['Title'] = data['Title'].replace('Mlle', 'Miss')
    data['Title'] = data['Title'].replace('Ms', 'Miss')
    data['Title'] = data['Title'].replace('Mme', 'Mrs')
    title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
    data['Title'] = data['Title'].map(title_mapping)
    data['Title'] = data['Title'].fillna(0)
       
    # Разделим на типы информацию о билетах
    data['Ticket_type'] = data['Ticket'].apply(lambda x: x[0:3])
    data['Ticket_type'] = data['Ticket_type'].astype('category')
    data['Ticket_type'] = data['Ticket_type'].cat.codes
    
    # Разделим Cabin на категории
    data['Cabin'] = data['Cabin'].fillna('U')
    data['Cabin'] = data['Cabin'].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
    cabin_category = {'A':9, 'B':8, 'C':7, 'D':6, 'E':5, 'F':4, 'G':3, 'T':2, 'U':1}
    data['Cabin'] = data['Cabin'].map(cabin_category)


    
    # Удалим ненужные колонки
    data.drop('SibSp', axis=1, inplace=True)
    data.drop('Parch', axis=1, inplace=True)
    data.drop(["PassengerId", "Name", "Ticket",'Pclass','Embarked', 'Sex'], axis=1, inplace=True)
    return data
    
# Clean train, test data
X_train = clean_data(train_data)
X_train.drop("Survived", axis=1, inplace=True)
X_test = clean_data(test_data)
X_test['Fare'].fillna(X_test['Fare'].median(), inplace=True)

X_train.info()
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          891 non-null    float64
#  1   Fare         891 non-null    float64
#  2   Cabin        891 non-null    int64
#  3   Family       891 non-null    int64
#  4   Q            891 non-null    bool
#  5   S            891 non-null    bool
#  6   2            891 non-null    bool
#  7   3            891 non-null    bool
#  8   is_minor     891 non-null    int32
#  9   Words_Count  891 non-null    int64
#  10  Title        891 non-null    int64
#  11  Ticket_type  891 non-null    int16
# dtypes: bool(4), float64(2), int16(1), int32(1), int64(4)
# memory usage: 50.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB

# %%
from sklearn.model_selection import train_test_split
train_x, val_x, train_y, val_y = train_test_split(X_train, Y_train, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error


random_forest = RandomForestClassifier(n_estimators=200)
random_forest.fit(train_x, train_y)

rand_pred = random_forest.predict(val_x)
print("Mean Absolute Error: " + str(1 - mean_absolute_error(rand_pred, val_y)))
# Out:
# Mean Absolute Error: 0.8430493273542601

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('submission_forest_avdvanced.csv', index=False)

# %% [markdown]
# ### Логистическая регрессия

# %%
import optuna
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

print(X_train.shape, Y_train.shape)

X_train, X_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

def objective(trial):
    # Определяем гиперпараметры для подбора
    C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])  # L1 и L2 регуляризация
    solver = trial.suggest_categorical('solver', ['liblinear', 'saga'])  # Подходящие солверы

    # Обучаем модель с выбранными гиперпараметрами
    logreg = LogisticRegression(max_iter = 100, random_state=42, C = 0.1)
    logreg.fit(X_train, y_train)

    # Предсказания и оценка
    y_pred_prob = logreg.predict(X_val)
    score = 1 - mean_absolute_error(rand_pred, val_y)

    return score

study = optuna.create_study(direction='maximize')  # Максимизируем MSE
study.optimize(objective, n_trials=100)  # Запускаем 100 итераций


# Получаем лучшие параметры
best_params = study.best_params
best_score = study.best_value

print(f'Лучшие параметры: {best_params}')
print(f'Лучший ROC AUC: {best_score}')

# Обучаем модель с лучшими параметрами
best_model = LogisticRegression(**best_params, max_iter=200)
best_model.fit(X_train, y_train)

# Оценка на валидационном наборе
y_pred_prob_best = best_model.predict_proba(X_val)[:, 1]
roc_auc_best = roc_auc_score(y_val, y_pred_prob_best)
print(f'ROC AUC на валидационном наборе с лучшими параметрами: {roc_auc_best}')
# Out:
# [I 2024-10-15 15:20:19,258] A new study created in memory with name: no-name-a9cc4fe1-6133-4b12-b654-9e10c340fe92
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,317] Trial 0 finished with value: 0.8430493273542601 and parameters: {'C': 0.006242924351955979, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,374] Trial 1 finished with value: 0.8430493273542601 and parameters: {'C': 2.117325569738821, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,437] Trial 2 finished with value: 0.8430493273542601 and parameters: {'C': 0.0008182673914160531, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# (891, 12) (891,)
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,515] Trial 3 finished with value: 0.8430493273542601 and parameters: {'C': 0.42984885829204944, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,602] Trial 4 finished with value: 0.8430493273542601 and parameters: {'C': 0.0006587141461936209, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,688] Trial 5 finished with value: 0.8430493273542601 and parameters: {'C': 0.0006735246201344011, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,757] Trial 6 finished with value: 0.8430493273542601 and parameters: {'C': 0.0011550313979995562, 'penalty': 'l2', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,829] Trial 7 finished with value: 0.8430493273542601 and parameters: {'C': 0.0005081030153877791, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,890] Trial 8 finished with value: 0.8430493273542601 and parameters: {'C': 1.1184155748700109, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:19,985] Trial 9 finished with value: 0.8430493273542601 and parameters: {'C': 0.014242364850615077, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,097] Trial 10 finished with value: 0.8430493273542601 and parameters: {'C': 0.02874931385152648, 'penalty': 'l2', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,176] Trial 11 finished with value: 0.8430493273542601 and parameters: {'C': 65.17228906211966, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,278] Trial 12 finished with value: 0.8430493273542601 and parameters: {'C': 9.507488540760722, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,376] Trial 13 finished with value: 0.8430493273542601 and parameters: {'C': 0.16156385732444356, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,461] Trial 14 finished with value: 0.8430493273542601 and parameters: {'C': 3.553690494573578, 'penalty': 'l2', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,529] Trial 15 finished with value: 0.8430493273542601 and parameters: {'C': 0.012296173342096366, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,616] Trial 16 finished with value: 0.8430493273542601 and parameters: {'C': 0.00011310779264113673, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,696] Trial 17 finished with value: 0.8430493273542601 and parameters: {'C': 0.07562216315145927, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,761] Trial 18 finished with value: 0.8430493273542601 and parameters: {'C': 44.5204147751908, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,829] Trial 19 finished with value: 0.8430493273542601 and parameters: {'C': 6.857693751370217, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,891] Trial 20 finished with value: 0.8430493273542601 and parameters: {'C': 0.004173272601234016, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:20,960] Trial 21 finished with value: 0.8430493273542601 and parameters: {'C': 0.0035209852826849474, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,213] Trial 22 finished with value: 0.8430493273542601 and parameters: {'C': 0.00019592044806914855, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,285] Trial 23 finished with value: 0.8430493273542601 and parameters: {'C': 0.003008981137722273, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,354] Trial 24 finished with value: 0.8430493273542601 and parameters: {'C': 0.0723689709820788, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,490] Trial 25 finished with value: 0.8430493273542601 and parameters: {'C': 1.0162415023513751, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,606] Trial 26 finished with value: 0.8430493273542601 and parameters: {'C': 0.008848847505881777, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,710] Trial 27 finished with value: 0.8430493273542601 and parameters: {'C': 0.001551220595267163, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,807] Trial 28 finished with value: 0.8430493273542601 and parameters: {'C': 0.2360687324550125, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:21,906] Trial 29 finished with value: 0.8430493273542601 and parameters: {'C': 0.5435909345162935, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,020] Trial 30 finished with value: 0.8430493273542601 and parameters: {'C': 0.03935078750306244, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,151] Trial 31 finished with value: 0.8430493273542601 and parameters: {'C': 0.464698989590207, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,280] Trial 32 finished with value: 0.8430493273542601 and parameters: {'C': 3.3020750677589685, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,389] Trial 33 finished with value: 0.8430493273542601 and parameters: {'C': 0.0006280701585026799, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,472] Trial 34 finished with value: 0.8430493273542601 and parameters: {'C': 19.28152128658575, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,588] Trial 35 finished with value: 0.8430493273542601 and parameters: {'C': 2.005298962977383, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,672] Trial 36 finished with value: 0.8430493273542601 and parameters: {'C': 0.3221460825512152, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,787] Trial 37 finished with value: 0.8430493273542601 and parameters: {'C': 0.00028039009452776755, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:22,889] Trial 38 finished with value: 0.8430493273542601 and parameters: {'C': 0.0009895627017336725, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:23,000] Trial 39 finished with value: 0.8430493273542601 and parameters: {'C': 0.027320711915441217, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:23,089] Trial 40 finished with value: 0.8430493273542601 and parameters: {'C': 1.0916808486728151, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:23,199] Trial 41 finished with value: 0.8430493273542601 and parameters: {'C': 0.0018070889444713979, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:23,289] Trial 42 finished with value: 0.8430493273542601 and parameters: {'C': 0.0003968244112853529, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:23,407] Trial 43 finished with value: 0.8430493273542601 and parameters: {'C': 0.006585706735854686, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:23,502] Trial 44 finished with value: 0.8430493273542601 and parameters: {'C': 0.0008640872813681447, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# ...
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:26,936] Trial 85 finished with value: 0.8430493273542601 and parameters: {'C': 0.0008177563771468862, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,010] Trial 86 finished with value: 0.8430493273542601 and parameters: {'C': 4.7255908334363665, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,083] Trial 87 finished with value: 0.8430493273542601 and parameters: {'C': 0.9747987866613421, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,171] Trial 88 finished with value: 0.8430493273542601 and parameters: {'C': 0.000367308843597618, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,232] Trial 89 finished with value: 0.8430493273542601 and parameters: {'C': 0.010748772377831547, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,304] Trial 90 finished with value: 0.8430493273542601 and parameters: {'C': 0.11936040260217302, 'penalty': 'l2', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,380] Trial 91 finished with value: 0.8430493273542601 and parameters: {'C': 0.002407702792701013, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,606] Trial 92 finished with value: 0.8430493273542601 and parameters: {'C': 0.0005437730718927068, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,689] Trial 93 finished with value: 0.8430493273542601 and parameters: {'C': 0.3455790833410519, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,758] Trial 94 finished with value: 0.8430493273542601 and parameters: {'C': 0.021987628116225188, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,821] Trial 95 finished with value: 0.8430493273542601 and parameters: {'C': 1.2327768138912967, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,876] Trial 96 finished with value: 0.8430493273542601 and parameters: {'C': 0.18778286137827274, 'penalty': 'l2', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:27,960] Trial 97 finished with value: 0.8430493273542601 and parameters: {'C': 0.0014212755817683835, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:28,026] Trial 98 finished with value: 0.8430493273542601 and parameters: {'C': 0.003773253668015411, 'penalty': 'l2', 'solver': 'saga'}. Best is trial 0 with value: 0.8430493273542601.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16896\1376411852.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e2)  # Пробуем различные значения C
# D:\Jupyter\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-10-15 15:20:28,106] Trial 99 finished with value: 0.8430493273542601 and parameters: {'C': 0.046461257025176124, 'penalty': 'l1', 'solver': 'liblinear'}. Best is trial 0 with value: 0.8430493273542601.
# Лучшие параметры: {'C': 0.006242924351955979, 'penalty': 'l2', 'solver': 'liblinear'}
# Лучший ROC AUC: 0.8430493273542601
# ROC AUC на валидационном наборе с лучшими параметрами: 0.8643500643500643

# %%
predictions = best_model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('submission_logreg_tuned.csv', index=False)

# %% [markdown]
# Получили score = 0.70813. Оставляем Random_Forest
